# %% [markdown]
# <a href="https://colab.research.google.com/github/sravankoyyada/Quantum_Computing_D-wave_major_project/blob/main/Knapsack_Optimization_Quantum_Computing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install dimod
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 29.2 MB/s eta 0:00:00
# ...

# %%
# !pip install dwave-system
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.5/100.5 kB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.6/158.6 kB 9.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.7/103.7 kB 9.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 43.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 30.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 49.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 31.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.5/225.5 kB 18.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 4.4 MB/s eta 0:00:00
# ...

# %%
# !pip install dwave-ocean-sdk
import os
from dwave.system import LeapHybridCQMSampler
from dimod import Binary, quicksum, ConstrainedQuadraticModel
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 36.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 69.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: dwave-optimization
#     Found existing installation: dwave-optimization 0.4.3
#     Uninstalling dwave-optimization-0.4.3:
#       Successfully uninstalled dwave-optimization-0.4.3
# ...

# %%
import dwave.system
from dimod import ConstrainedQuadraticModel, Binary, quicksum
from dwave.system import LeapHybridCQMSampler
from dimod import Binary, quicksum, ConstrainedQuadraticModel

# %%
values = [34,25,78,21,64]
weights= [3,5,9,4,2]
W = 10
n=len(values)

# %%
 from dwave.system import LeapHybridCQMSampler
from dwave.cloud import Client

# Set up the API token explicitly (optional if using `dwave config`)
#token = "DEV-8ebd2b02e73842c808d668eab3764b39664d9d47"  # Replace with your actual token
#Client.from_config(token=token)

# Problem parameters

values = [10, 50, 30, 40, 50]
weights = [1, 2, 3, 4, 5]
W = 10
n = len(values)

# Create binary variables
x = [Binary(f'x{i}') for i in range(n)]

# Construct the CQM
cqm = ConstrainedQuadraticModel()

# Add the objective function
cqm.set_objective(sum(-values[i] * x[i] for i in range(n)))

# Add the constraints
cqm.add_constraint(sum(weights[i] * x[i] for i in range(n)) <= W, label='max weight')
cqm.add_constraint(sum(x[i] for i in range(n)) <= n, label='max items')

# Submit to the CQM sampler
token = "DEV-8ebd2b02e73842c808d668eab3764b39664d9d47"
sampler = LeapHybridCQMSampler(token=token)
sampleset = sampler.sample_cqm(cqm)

# Display the full sample set
print("\nFull sample set:")
print(sampleset)
# Out:
# Full sample set:
#      x0  x1  x2  x3  x4 energy num_oc. is_sat. is_fea.
# 112 0.0 1.0 0.0 1.0 1.0 -140.0       1 arra...   False
# 113 1.0 1.0 1.0 0.0 1.0 -140.0       1 arra...   False
# 114 0.0 1.0 0.0 1.0 1.0 -140.0       1 arra...   False
# 115 0.0 1.0 0.0 1.0 1.0 -140.0       1 arra...   False
# 116 0.0 1.0 0.0 1.0 1.0 -140.0       1 arra...   False
# 117 0.0 1.0 0.0 1.0 1.0 -140.0       1 arra...   False
# 118 0.0 1.0 0.0 1.0 1.0 -140.0       1 arra...   False
# 119 0.0 1.0 0.0 1.0 1.0 -140.0       1 arra...   False
# 120 0.0 1.0 0.0 1.0 1.0 -140.0       1 arra...   False
# 121 0.0 1.0 0.0 1.0 1.0 -140.0       1 arra...   False
# 122 0.0 1.0 0.0 1.0 1.0 -140.0       1 arra...   False
# 123 0.0 1.0 0.0 1.0 1.0 -140.0       1 arra...   False
# 124 0.0 1.0 0.0 1.0 1.0 -140.0       1 arra...   False
# 125 0.0 1.0 0.0 1.0 1.0 -140.0       1 arra...   False
# 126 0.0 1.0 0.0 1.0 1.0 -140.0       1 arra...   False
# 127 0.0 1.0 0.0 1.0 1.0 -140.0       1 arra...   False
# ...
